# %%
import importlib
import pyace as pya
importlib.reload(pya)
from __future__ import unicode_literals
import youtube_dl 
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dcw10\\Python jupyter code\\pyace-master\\pyace'

# %%
songpath="./海上的人.wav"
respath='.chords.txt'
modelpath='C:\\Users\\dcw10\\Python jupyter code\\pyace-master\\pretrained_model\\model\\lstmrnn512\\CJKURB.cg.model'
acemode='rnn'
pya.deepace(songpath, respath,  acemode,modelpath)
# Out:
# feature extraction...
# hmm setup...
# generating segmentation...
# 0 2.577 A#:min
# 2.577 4.319 C
# 4.319 6.2 G#
# 6.2 8.127 A#:min
# 8.127 9.381 C#
# 9.381 10.937 G#
# 10.937 11.889 C:min
# 11.889 13.166 F:min
# 13.166 15.72 C:min
# 15.72 18.808 C#
# 18.808 23.382 D#
# 23.382 25.31 G#
# 25.31 26.401 D#:min
# 26.401 26.982 C:min
# 26.982 28.955 F:min
# 28.955 30.813 C:min
# 30.813 32.531 C#
# 32.531 34.551 G#
# 34.551 36.432 A#:min
# 36.432 38.336 D#:min
# 38.336 39.962 G#
# 39.962 42.144 D#
# 42.144 43.816 F:min
# 43.816 46.045 G#
# 46.045 47.02 C#
# 47.02 49.807 G#
# 49.807 50.712 C#
# 50.712 51.688 D#
# 51.688 61.417 G#
# 61.417 62.462 A#
# 62.462 63.948 G#
# 63.948 66.781 C:min
# 66.781 68.731 C#
# 68.731 70.078 D#
# 70.078 72.539 G#
# 72.539 74.35 D#
# 74.35 76.301 F:min
# 76.301 78.274 C:min
# 78.274 79.784 C#
# 79.784 81.99 G#
# 81.99 83.894 A#:min
# 83.894 85.078 C:min
# 85.078 85.473 F#
# 85.473 87.632 F:min
# 87.632 89.583 D#
# 89.583 91.138 C#
# 91.138 93.275 G#
# 93.275 95.248 F:min
# 95.248 97.176 D#
# 97.176 98.917 C#
# 98.917 100.914 D#
# 100.914 102.864 G#
# 102.864 104.768 A#:min
# 104.768 106.046 C#
# 106.046 107.462 G#
# 107.462 108.437 D#
# 108.437 110.109 F:min
# 110.109 112.268 C:min
# 112.268 114.196 C#
# 114.196 115.844 D#:min
# 115.844 118.004 G#
# 118.004 119.908 A#:min
# 119.908 121.278 C#
# 121.278 122.508 G#
# 122.508 123.669 D#
# 123.669 125.899 F:min
# 125.899 127.408 C:min
# 127.408 131.193 C#
# 131.193 131.889 D#
# 131.889 133.19 A#:min
# 133.19 134.026 D#
# 134.026 137.021 G#
# 137.021 139.714 A#:min
# 139.714 141.363 G#
# 141.363 142.594 C:min
# 142.594 143.894 F:min
# 143.894 146.309 C:min
# 146.309 147.702 C#
# 147.702 148.445 G#
# 148.445 150.187 D#
# 150.187 152.137 G#
# 152.137 153.321 A#:min
# 153.321 154.064 G#:min
# 154.064 155.318 C#
# 155.318 156.92 G#
# 156.92 157.826 G:min
# 157.826 159.126 F:min
# 159.126 161.495 C:min
# 161.495 165.256 C#
# 165.256 169.227 D#
# 169.227 170.992 D:min
# 170.992 172.942 D#
# 172.942 174.939 C#:min
# 174.939 175.845 G#
# 175.845 176.611 C:min
# 176.611 178.608 F:min
# 178.608 180.489 D#
# 180.489 182.555 C#:min
# 182.555 186.154 D#
# 186.154 188.151 G#
# 188.151 189.962 D#:min
# 189.962 191.263 C#
# 191.263 193.562 C:min
# 193.562 195.094 F:min
# 195.094 197.509 C:min
# 197.509 198.879 C#
# 198.879 199.576 G#
# 199.576 201.085 D#:min
# 201.085 203.314 G#
# 203.314 206.472 A#:min
# 206.472 207.935 G#
# 207.935 208.98 D#
# 208.98 210.257 F:min
# 210.257 212.695 C:min
# 212.695 216.503 C#
# 216.503 217.548 D#:min
# 217.548 218.36 A#:min
# 218.36 219.336 G:min
# 219.336 223.237 G#
# 223.237 224.073 C:min
# 224.073 226.069 C#
# 226.069 227.23 D#
# 227.23 228.786 G#
# 228.786 231.805 C:min
# 231.805 234.196 C#
# segment tiling...
# classifying...
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# generating output...
# test: 0 2.577 N
# test: 2.577 4.319 N
# test: 4.319 6.2 G#
# test: 6.2 8.127 A#:min
# test: 8.127 9.381 C#
# test: 9.381 10.937 G#
# test: 10.937 11.889 D#
# test: 11.889 13.166 C#
# test: 13.166 15.72 G#
# test: 15.72 18.808 C#
# test: 18.808 23.382 D#
# test: 23.382 25.31 G#
# test: 25.31 26.401 D#
# test: 26.401 26.982 D#
# test: 26.982 28.955 F:min
# test: 28.955 30.813 C:min
# test: 30.813 32.531 C#
# test: 32.531 34.551 G#
# test: 34.551 36.432 A#:min
# test: 36.432 38.336 D#
# test: 38.336 39.962 G#
# test: 39.962 42.144 D#
# test: 42.144 43.816 F:min
# test: 43.816 46.045 G#
# test: 46.045 47.02 C#
# test: 47.02 49.807 G#
# test: 49.807 50.712 C#
# test: 50.712 51.688 D#
# test: 51.688 61.417 G#
# test: 61.417 62.462 A#
# test: 62.462 63.948 G#
# test: 63.948 66.781 G#
# test: 66.781 68.731 C#
# test: 68.731 70.078 D#
# test: 70.078 72.539 G#
# test: 72.539 74.35 D#
# test: 74.35 76.301 F:min
# test: 76.301 78.274 G#
# test: 78.274 79.784 C#
# test: 79.784 81.99 G#
# test: 81.99 83.894 A#:min
# test: 83.894 85.078 C:min
# test: 85.078 85.473 A#
# test: 85.473 87.632 F:min
# test: 87.632 89.583 D#
# test: 89.583 91.138 C#
# test: 91.138 93.275 G#
# test: 93.275 95.248 F:min
# test: 95.248 97.176 D#
# test: 97.176 98.917 C#
# test: 98.917 100.914 D#
# test: 100.914 102.864 G#
# test: 102.864 104.768 A#:min
# test: 104.768 106.046 C#
# test: 106.046 107.462 G#
# test: 107.462 108.437 D#
# test: 108.437 110.109 F:min
# test: 110.109 112.268 G#
# test: 112.268 114.196 C#
# test: 114.196 115.844 D#
# test: 115.844 118.004 G#
# test: 118.004 119.908 A#:min
# test: 119.908 121.278 C#
# test: 121.278 122.508 G#
# test: 122.508 123.669 D#
# test: 123.669 125.899 F:min
# test: 125.899 127.408 C:min
# test: 127.408 131.193 C#
# test: 131.193 131.889 D#
# test: 131.889 133.19 D#
# test: 133.19 134.026 D#
# test: 134.026 137.021 G#
# test: 137.021 139.714 A#:min
# test: 139.714 141.363 G#
# test: 141.363 142.594 C:min
# test: 142.594 143.894 F:min
# test: 143.894 146.309 C:min
# test: 146.309 147.702 C#
# test: 147.702 148.445 G#
# test: 148.445 150.187 D#
# test: 150.187 152.137 G#
# test: 152.137 153.321 A#
# test: 153.321 154.064 G#
# test: 154.064 155.318 C#
# test: 155.318 156.92 G#
# test: 156.92 157.826 D#
# test: 157.826 159.126 F:min
# test: 159.126 161.495 G#
# test: 161.495 165.256 C#
# test: 165.256 169.227 D#
# test: 169.227 170.992 F:min
# test: 170.992 172.942 D#
# test: 172.942 174.939 C#
# test: 174.939 175.845 G#
# test: 175.845 176.611 C
# test: 176.611 178.608 F:min
# test: 178.608 180.489 D#
# test: 180.489 182.555 C#
# test: 182.555 186.154 D#
# test: 186.154 188.151 G#
# test: 188.151 189.962 D#
# test: 189.962 191.263 C#
# test: 191.263 193.562 G#
# test: 193.562 195.094 F
# test: 195.094 197.509 C:min
# test: 197.509 198.879 C#
# test: 198.879 199.576 C
# test: 199.576 201.085 D#
# test: 201.085 203.314 G#
# test: 203.314 206.472 A#:min
# test: 206.472 207.935 G#
# test: 207.935 208.98 D#
# test: 208.98 210.257 F:min
# test: 210.257 212.695 G#
# test: 212.695 216.503 C#
# test: 216.503 217.548 D#
# test: 217.548 218.36 A#
# test: 218.36 219.336 D#
# test: 219.336 223.237 G#
# test: 223.237 224.073 C:min
# test: 224.073 226.069 C#
# test: 226.069 227.23 D#
# test: 227.23 228.786 G#
# test: 228.786 231.805 G#
# test: 231.805 234.196 C#

# %%
# Out:
# <module 'pyace' from 'C:\\Users\\dcw10\\Python jupyter code\\pyace-master\\pyace\\pyace.py'>

# %%
from __future__ import unicode_literals
import youtube_dl


song_title='海上的人'
outtmpl = song_title + '.%(ext)s'
ydl_opts = {
    'format': 'bestaudio/best',
    'outtmpl': outtmpl,
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        
        'preferredcodec': 'wav',
        'preferredquality': '192'
    }],
    'postprocessor_args': [
        '-ar', '16000'
    ],
    'prefer_ffmpeg': True,
    'keepvideo': True,
    
}
#change file name here


with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    ydl.download(['https://www.youtube.com/watch?v=u3cKrp96i_M'])
# Out:
# [youtube] u3cKrp96i_M: Downloading webpage
# [youtube] u3cKrp96i_M: Downloading video info webpage
# [download] Destination: 海上的人.webm
# [download] 100% of 3.57MiB in 00:00
# [ffmpeg] Destination: 海上的人.wav

# %%
def download_song(song_url, song_title):
    """
    Download a song using youtube url and song title
    """

    outtmpl = song_title + '.%(ext)s'
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': outtmpl,
        'postprocessors': [
            {'key': 'FFmpegExtractAudio','preferredcodec': 'wav',
             'preferredquality': '192',
            },
            {'key': 'FFmpegMetadata'},
        ],
    }

    with youtube_dl.YoutubeDL(ydl_opts) as ydl:
        info_dict = ydl.extract_info(song_url, download=True)

# %%
song_url='https://www.youtube.com/watch?v=u3cKrp96i_M'
song_title='海上的人'
download_song(song_url,song_title)
# Out:
# [youtube] u3cKrp96i_M: Downloading webpage
# [youtube] u3cKrp96i_M: Downloading video info webpage
# [youtube] u3cKrp96i_M: Downloading js player vflca9-f7
# [download] Destination: 海上的人.webm
# [download] 100% of 3.57MiB in 00:00
# [ffmpeg] Destination: 海上的人.wav
# Deleting original file 海上的人.webm (pass -k to keep)
# [ffmpeg] Adding metadata to '海上的人.wav'

# %%
respath='.chords.txt'
fw = open(respath,'w')

fw.write('123')
fw.close()
