# %%
import importlib
import pyace as pya
importlib.reload(pya)
from __future__ import unicode_literals
import youtube_dl 
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dcw10\\Python jupyter code\\Ultimate_GuitarTab_Craw\\ultimate-guitar-tab-crawl\\Python_code\\chord_detector\\pyace'

# %%
songpath="./Owl City - On The Wing.mp3"
respath='.chords.txt'
modelpath='C:\\Users\\dcw10\\Python jupyter code\\pyace-master\\pretrained_model\\model\\lstmrnn512\\CJKURB.cg.model'
acemode='rnn'
chord_infor=pya.deepace(songpath, respath,  acemode,modelpath)
# Out:
# feature extraction...
# hmm setup...
# generating segmentation...
# segment tiling...
# classifying...
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# generating output...
# retrieve chord_info successfully

# %%
chord_infor
# Out:
# [{'et': 8.638, 'ochord': 'A#', 'st': 0},
#  {'et': 9.729, 'ochord': 'A#', 'st': 8.638},
#  {'et': 10.751, 'ochord': 'D#', 'st': 9.729},
#  {'et': 11.749, 'ochord': 'G:min', 'st': 10.751},
#  {'et': 12.771, 'ochord': 'D#', 'st': 11.749},
#  {'et': 13.909, 'ochord': 'A#', 'st': 12.771},
#  {'et': 14.93, 'ochord': 'D#', 'st': 13.909},
#  {'et': 15.906, 'ochord': 'G:min', 'st': 14.93},
#  {'et': 16.951, 'ochord': 'D#', 'st': 15.906},
#  {'et': 18.019, 'ochord': 'A#', 'st': 16.951},
#  {'et': 19.203, 'ochord': 'D#', 'st': 18.019},
#  {'et': 20.062, 'ochord': 'G:min', 'st': 19.203},
#  {'et': 22.221, 'ochord': 'A#', 'st': 20.062},
#  {'et': 23.382, 'ochord': 'D#', 'st': 22.221},
#  {'et': 24.242, 'ochord': 'G:min', 'st': 23.382},
#  {'et': 26.378, 'ochord': 'A#', 'st': 24.242},
#  {'et': 33.622, 'ochord': 'D#', 'st': 26.378},
#  {'et': 34.714, 'ochord': 'A#', 'st': 33.622},
#  {'et': 40.96, 'ochord': 'D#', 'st': 34.714},
#  {'et': 42.167, 'ochord': 'F', 'st': 40.96},
# ...

# %%
chord=[]
for i in chord_infor:
    chord.append(i['ochord'])
chord
# Out:
# ['A#',
#  'A#',
#  'D#',
#  'G:min',
#  'D#',
#  'A#',
#  'D#',
#  'G:min',
#  'D#',
#  'A#',
#  'D#',
#  'G:min',
#  'A#',
#  'D#',
#  'G:min',
#  'A#',
#  'D#',
#  'A#',
#  'D#',
#  'F',
#  'A#',
#  'F',
#  'C',
#  'C',
#  'D#',
#  'C',
#  'A#',
#  'F',
#  'C:min',
#  'D#',
#  'F',
#  'A#',
#  'F',
#  'C',
#  'D#',
#  'A#',
#  'F',
#  'C',
#  'D#',
#  'F',
#  'G:min',
#  'C:min',
#  'A#',
#  'D#',
#  'A#',
#  'D#',
#  'A#',
#  'D#',
#  'F',
#  'A#',
#  'F',
#  'C:min',
#  'D#',
#  'C:min',
#  'A#',
#  'F',
#  'C:min',
#  'D#',
#  'A#',
#  'F',
#  'C',
#  'D#',
#  'A#',
#  'F',
#  'C',
#  'D#',
#  'F',
#  'C',
#  'C:min',
#  'D#',
#  'A#',
#  'F',
#  'D#',
#  'A#',
#  'F',
#  'D#',
#  'F',
#  'D#',
#  'A#',
#  'F',
#  'D#',
#  'A#',
#  'F',
#  'D#',
#  'A#',
#  'F',
#  'D#',
#  'F',
#  'D#',
#  'A#',
#  'F',
#  'A#',
#  'G:min',
#  'F',
#  'C',
#  'A#',
#  'F',
#  'D#',
#  'F',
#  'G:min',
#  'A#',
#  'F',
#  'A#',
#  'F',
#  'D#',
#  'A#',
#  'G:min',
#  'F',
#  'C:min',
#  'A#',
# ...

# %%
from __future__ import unicode_literals
import youtube_dl


song_title='海上的人'
outtmpl = song_title + '.%(ext)s'
ydl_opts = {
    'format': 'bestaudio/best',
    'outtmpl': outtmpl,
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '192',
    }],
    
}
#change file name here


with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    ydl.download(['https://www.youtube.com/watch?v=u3cKrp96i_M'])
# Out:
# [youtube] u3cKrp96i_M: Downloading webpage
# [youtube] u3cKrp96i_M: Downloading video info webpage
# [download] Destination: 海上的人.webm
# [download] 100% of 3.57MiB in 00:00
# [ffmpeg] Destination: 海上的人.mp3
# Deleting original file 海上的人.webm (pass -k to keep)

# %%
def download_song(song_url, song_title):
    """
    Download a song using youtube url and song title
    """

    outtmpl = song_title + '.%(ext)s'
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': outtmpl,
        'postprocessors': [
            {'key': 'FFmpegExtractAudio','preferredcodec': 'mp3',
             'preferredquality': '192',
            },
            {'key': 'FFmpegMetadata'},
        ],
    }

    with youtube_dl.YoutubeDL(ydl_opts) as ydl:
        info_dict = ydl.extract_info(song_url, download=True)

# %%
song_url='https://www.youtube.com/watch?v=IUAdrGKW-94'
song_title='Owl City - On The Wing'
download_song(song_url,song_title)
# Out:
# [youtube] IUAdrGKW-94: Downloading webpage
# [youtube] IUAdrGKW-94: Downloading video info webpage
# [download] Destination: Owl City - On The Wing.webm
# [download] 100% of 5.16MiB in 00:02
# [ffmpeg] Destination: Owl City - On The Wing.mp3
# Deleting original file Owl City - On The Wing.webm (pass -k to keep)
# [ffmpeg] Adding metadata to 'Owl City - On The Wing.mp3'

# %%
respath='.chords.txt'
fw = open(respath,'w')

fw.write('123')
fw.close()
